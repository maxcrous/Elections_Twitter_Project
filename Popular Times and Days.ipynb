# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import json 
tweets_collection = r'C:\Users\user\Downloads\geotagged_tweets_20160812-0912.jsons'
tweets_file = open(tweets_collection, "r")
tweets_data=[]
days={}
times={}

# %%
for idx, line in enumerate(tweets_file):
    try:
        tweet = json.loads(line)
        day(tweet['created_at'])
    except Exception as e:
        continue
    if idx%50000==0:
        print(idx)
# Out:
# 0
# 50000
# 100000
# 150000
# 200000
# 250000
# 300000
# 350000
# 400000
# 450000
# 500000
# 550000
# 600000
# 650000

# %%
def day(cr):
    day=cr[:3]
    if day in days.keys():
        days[day]=days[day]+1
    else:
        days[day]=1
    time=cr[11:13]
    if time in times.keys():
        times[time]=times[time]+1
    else:
        times[time]=1

# %%
days
# Out:
# {'Fri': 104006,
#  'Sat': 105160,
#  'Sun': 92557,
#  'Mon': 86056,
#  'Tue': 72945,
#  'Wed': 88438,
#  'Thu': 108145}

# %%
times
# Out:
# {'10': 10001,
#  '11': 17151,
#  '12': 24676,
#  '13': 30283,
#  '14': 33536,
#  '15': 34120,
#  '16': 35222,
#  '17': 35739,
#  '18': 35083,
#  '19': 34363,
#  '20': 35195,
#  '21': 34988,
#  '22': 35083,
#  '23': 39207,
#  '00': 42658,
#  '01': 41253,
#  '02': 42078,
#  '03': 31357,
#  '04': 22235,
#  '05': 15157,
#  '06': 9966,
#  '07': 6921,
#  '08': 5401,
#  '09': 5634}

# %%
plt.pie(days.values(),labels=days.keys(),colors=['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','brown','orange'],shadow=True,autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %%
plt.pie(times.values(),labels=[i+'.00-'+i+'.59' for i in times.keys()],shadow=True,autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %%
plt.plot(times.keys(),times.values())
plt.show()
